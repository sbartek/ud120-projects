# %%
from plotthem import plotTrain
from class_vis import prettyPicture
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from prep_terrain_data import makeTerrainData
features_train, labels_train, features_test, labels_test = makeTerrainData()

# %%
from sklearn.neighbors import KNeighborsClassifier
clfK = KNeighborsClassifier(n_neighbors=10)
clfK.fit(features_train, labels_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=10, p=2,
#            weights='uniform')

# %%
pred = clfK.predict(features_test)
from sklearn.metrics import accuracy_score
accuracy_score(pred, labels_test)
# Out:
# 0.93200000000000005

# %%
plotTrain(features_train, labels_train)

# %%
prettyPicture(clfK, features_test, labels_test)
